# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
from sklearn.datasets import make_blobs

# %%
data=make_blobs(
    n_samples=200,
    n_features=2,
    centers=4,
    cluster_std=1.8,
    random_state=101,
)

# %%
data[0].shape
# Out:
# (200, 2)

# %%
plt.scatter(data[0][:,0],data[0][:,1],c=data[1])

# %%
data[1]
# Out:
# array([3, 2, 0, 2, 2, 1, 2, 0, 2, 0, 3, 0, 2, 2, 3, 0, 2, 0, 1, 3, 1, 0,
#        0, 1, 3, 1, 1, 0, 2, 2, 3, 1, 2, 0, 0, 3, 1, 1, 1, 2, 1, 3, 3, 3,
#        0, 3, 3, 0, 1, 2, 0, 3, 2, 0, 1, 3, 0, 0, 3, 2, 1, 2, 1, 3, 2, 0,
#        1, 2, 2, 1, 2, 0, 1, 3, 1, 2, 2, 0, 3, 0, 0, 1, 2, 1, 0, 0, 0, 3,
#        2, 1, 1, 1, 1, 3, 0, 1, 2, 3, 1, 2, 0, 1, 0, 0, 2, 0, 1, 2, 1, 1,
#        0, 3, 3, 2, 1, 2, 3, 3, 2, 3, 0, 3, 0, 3, 0, 2, 3, 0, 1, 3, 3, 3,
#        0, 1, 1, 3, 2, 3, 2, 0, 1, 2, 1, 3, 3, 2, 0, 1, 3, 3, 3, 3, 0, 2,
#        0, 3, 2, 2, 2, 0, 2, 0, 0, 3, 1, 3, 0, 2, 3, 0, 2, 0, 3, 3, 0, 3,
#        2, 2, 1, 2, 3, 1, 1, 3, 1, 1, 1, 1, 1, 0, 1, 2, 2, 3, 1, 0, 2, 2,
#        1, 0])

# %%
from sklearn.cluster import KMeans

# %%
kmeans=KMeans(n_clusters=8)

# %%
kmeans.fit(data[0])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=8, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[ 5.41545402,  5.71409393],
#        [-9.18960987, -8.53584776],
#        [-6.08520212,  8.13834576],
#        [ 0.3431125 ,  0.55386311],
#        [-9.67203831, -5.13061964],
#        [-0.41887135,  3.96137019],
#        [ 2.89741486,  7.98651499],
#        [-2.74962486,  7.95519667]])

# %%
kmeans.labels_
# Out:
# array([2, 0, 5, 6, 0, 4, 6, 3, 6, 5, 2, 5, 6, 6, 2, 3, 0, 3, 4, 2, 4, 3,
#        5, 1, 2, 1, 1, 3, 6, 0, 7, 1, 0, 3, 5, 2, 4, 4, 1, 3, 4, 7, 7, 7,
#        5, 6, 7, 5, 1, 5, 3, 2, 0, 3, 4, 7, 5, 3, 7, 6, 1, 6, 4, 7, 6, 3,
#        4, 0, 6, 4, 6, 5, 4, 5, 4, 0, 6, 5, 2, 5, 5, 4, 6, 4, 3, 3, 3, 2,
#        5, 4, 1, 4, 4, 5, 5, 1, 6, 7, 4, 0, 5, 4, 5, 3, 5, 5, 4, 0, 1, 4,
#        0, 7, 7, 6, 1, 0, 7, 2, 6, 7, 5, 7, 3, 2, 3, 0, 2, 3, 1, 7, 7, 7,
#        3, 1, 4, 7, 0, 5, 6, 3, 1, 0, 4, 7, 7, 6, 5, 1, 7, 2, 7, 7, 3, 0,
#        3, 2, 5, 6, 6, 3, 6, 3, 5, 2, 4, 2, 5, 0, 7, 3, 6, 3, 2, 7, 5, 2,
#        6, 6, 1, 6, 7, 1, 1, 7, 4, 1, 4, 1, 1, 3, 4, 0, 6, 7, 4, 5, 0, 6,
#        4, 3])

# %%
fig , (ax1,ax2) = plt.subplots(1,2,sharey=True,figsize=(10,6))
ax1.set_title('K Means')
ax1.scatter(data[0][:,0],data[0][:,1],c=kmeans.labels_,cmap='rainbow')

ax2.set_title('Original')
ax2.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')
